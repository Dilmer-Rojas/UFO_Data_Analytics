# %% [markdown]
# # Cargar la data y convertir a sql para su posterior uso

# %%
import sqlite3 # Para manejo de bases de datos
import pandas as pd # Para manejo de dataframes

# %%
# Ver una muestra de los datos
df = pd.read_csv("../data/raw/ufo_data.csv")
print("✅ Datos cargados")
# Out:
# ✅ Datos cargados
# C:\Users\harri\AppData\Local\Temp\ipykernel_14800\1904575887.py:2: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/raw/ufo_data.csv")

# %%
df.head()
# Out:
#               datetime                  city state country     shape  \
# 0  1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1  1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2  1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3  1956-10-10 21:00:00                  edna    tx      us    circle
# 4  1960-10-10 20:00:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...  2004-04-27  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...  2008-01-21        53.2
# 3  My older brother and twin sister were leaving ...  2004-01-17  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...  2004-01-22  21.4180556
#
#    longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611

# %%
# Crearemos una conexión sqlite3
conexion = sqlite3.connect("../data/raw/ufo_data.db")

# Guardar el dataframe como tabla SQLite
df.to_sql("ufo_table", conexion, if_exists="replace", index=False) 
# El index col se usa para eliminar el Unnamed

print("✅ Base de datos creada correctamente...")

cursor = conexion.cursor()
# Out:
# ✅ Base de datos creada correctamente...

# %%
# Vamos a mostrar las 10 principales filas
consulta = """
           SELECT *
           FROM ufo_table
           LIMIT 10;
           """
resultado = pd.read_sql_query(consulta, conexion)
resultado
# Out:
#               datetime                  city state country     shape  \
# 0  1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1  1949-10-10 21:00:00          lackland afb    tx    None     light
# 2  1955-10-10 17:00:00  chester (uk/england)  None      gb    circle
# 3  1956-10-10 21:00:00                  edna    tx      us    circle
# 4  1960-10-10 20:00:00               kaneohe    hi      us     light
# 5  1961-10-10 19:00:00               bristol    tn      us    sphere
# 6  1965-10-10 21:00:00    penarth (uk/wales)  None      gb    circle
# 7  1965-10-10 23:45:00               norwalk    ct      us      disk
# 8  1966-10-10 20:00:00             pell city    al      us      disk
# 9  1966-10-10 21:00:00              live oak    fl      us      disk
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
# 5                300            5 minutes
# 6                180         about 3 mins
# 7               1200           20 minutes
# 8                180           3  minutes
# 9                120      several minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...  2004-04-27  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...  2008-01-21        53.2
# 3  My older brother and twin sister were leaving ...  2004-01-17  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...  2004-01-22  21.4180556
# 5  My father is now 89 my brother 52 the girl wit...  2007-04-27      36.595
# 6  penarth uk  circle  3mins  stayed 30ft above m...  2006-02-14   51.434722
# 7  A bright orange color changing to reddish colo...  1999-10-02     41.1175
# 8  Strobe Lighted disk shape object observed clos...  2009-03-19  33.5861111
# 9  Saucer zaps energy from powerline as my pregna...  2005-05-11  30.2947222
#
#    longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611
# 5  -82.188889
# 6   -3.180000
# 7  -73.408333
# 8  -86.286111
# 9  -82.984167
